# %%
import json
import requests
from IPython.display import clear_output

# %%
api_url_base= 'https://api.binance.com'

# %%
requests.get(api_url_base)
# Out:
# <Response [200]>

# %%
k = requests.get(api_url_base+'/api/'+'v3'+'/'+'ticker/price',params={'symbol':'ETHUSDT'})

# %%
k.content.decode('utf-8')
# Out:
# '{"symbol":"ETHUSDT","price":"601.35000000"}'

# %%
json.loads(k.content.decode('utf-8'))

# %%
y = requests.get(api_url_base+'/api/'+'v1'+'/'+'trades',params={'symbol':'ETHUSDT'})

# %%
json.loads(y.content.decode('utf-8'))
# Out:
# [{'id': 21628278,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.58000000',
#   'qty': '0.00001000',
#   'time': 1524348613710},
#  {'id': 21628279,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.17000000',
#   'qty': '0.59141000',
#   'time': 1524348622875},
#  {'id': 21628280,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.20000000',
#   'qty': '0.32735000',
#   'time': 1524348638008},
#  {'id': 21628281,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.40000000',
#   'qty': '0.23899000',
#   'time': 1524348641087},
#  {'id': 21628282,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.40000000',
#   'qty': '0.00181000',
#   'time': 1524348641671},
#  {'id': 21628283,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.56000000',
#   'qty': '0.09806000',
#   'time': 1524348641671},
#  {'id': 21628284,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.56000000',
#   'qty': '0.91678000',
#   'time': 1524348644049},
#  {'id': 21628285,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.58000000',
#   'qty': '0.02967000',
#   'time': 1524348644049},
#  {'id': 21628286,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.60000000',
#   'qty': '0.73155000',
#   'time': 1524348644049},
#  {'id': 21628287,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.60000000',
#   'qty': '1.65700000',
#   'time': 1524348644482},
#  {'id': 21628288,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.57000000',
#   'qty': '0.62005000',
#   'time': 1524348668704},
#  {'id': 21628289,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.60000000',
#   'qty': '0.10660000',
#   'time': 1524348668704},
#  {'id': 21628290,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.28113000',
#   'time': 1524348668704},
#  {'id': 21628291,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.40000000',
#   'time': 1524348669103},
#  {'id': 21628292,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.10670000',
#   'time': 1524348669751},
#  {'id': 21628293,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.33000000',
#   'qty': '0.08526000',
#   'time': 1524348670418},
#  {'id': 21628294,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.04997000',
#   'time': 1524348670929},
#  {'id': 21628295,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.40000000',
#   'time': 1524348673362},
#  {'id': 21628296,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.65000000',
#   'qty': '0.06648000',
#   'time': 1524348677280},
#  {'id': 21628297,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.33352000',
#   'time': 1524348677280},
#  {'id': 21628298,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.57000000',
#   'qty': '0.09981000',
#   'time': 1524348683024},
#  {'id': 21628299,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.57000000',
#   'qty': '0.13100000',
#   'time': 1524348684123},
#  {'id': 21628300,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.57000000',
#   'qty': '0.02100000',
#   'time': 1524348684195},
#  {'id': 21628301,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.57000000',
#   'qty': '0.00096000',
#   'time': 1524348686577},
#  {'id': 21628302,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.35809000',
#   'time': 1524348686577},
#  {'id': 21628303,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.01682000',
#   'time': 1524348686577},
#  {'id': 21628304,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.56000000',
#   'qty': '0.06649000',
#   'time': 1524348686692},
#  {'id': 21628305,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.01923000',
#   'time': 1524348692962},
#  {'id': 21628306,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.30577000',
#   'time': 1524348692962},
#  {'id': 21628307,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.14613000',
#   'time': 1524348694372},
#  {'id': 21628308,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.60000000',
#   'qty': '0.10001000',
#   'time': 1524348695504},
#  {'id': 21628309,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '1.65600000',
#   'time': 1524348697608},
#  {'id': 21628310,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.44000000',
#   'time': 1524348698933},
#  {'id': 21628311,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.76610000',
#   'time': 1524348699397},
#  {'id': 21628312,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.88990000',
#   'time': 1524348699397},
#  {'id': 21628313,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.27990000',
#   'time': 1524348699791},
#  {'id': 21628314,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.44000000',
#   'time': 1524348701019},
#  {'id': 21628315,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.66000000',
#   'qty': '0.38820000',
#   'time': 1524348701702},
#  {'id': 21628316,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.74000000',
#   'qty': '0.17261000',
#   'time': 1524348704349},
#  {'id': 21628317,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.74000000',
#   'qty': '0.04800000',
#   'time': 1524348707080},
#  {'id': 21628318,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.66000000',
#   'qty': '4.88056000',
#   'time': 1524348716518},
#  {'id': 21628319,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.74000000',
#   'qty': '0.00010000',
#   'time': 1524348719326},
#  {'id': 21628320,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.74000000',
#   'qty': '0.09985000',
#   'time': 1524348719326},
#  {'id': 21628321,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.74000000',
#   'qty': '0.00005000',
#   'time': 1524348719366},
#  {'id': 21628322,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.80000000',
#   'qty': '0.27609000',
#   'time': 1524348719366},
#  {'id': 21628323,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.80000000',
#   'qty': '0.00019000',
#   'time': 1524348719401},
#  {'id': 21628324,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.95000000',
#   'qty': '0.54648000',
#   'time': 1524348719401},
#  {'id': 21628325,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.95000000',
#   'qty': '0.00047000',
#   'time': 1524348720215},
#  {'id': 21628326,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.98000000',
#   'qty': '1.09275000',
#   'time': 1524348720215},
#  {'id': 21628327,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.98000000',
#   'qty': '0.17847000',
#   'time': 1524348720215},
#  {'id': 21628328,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.98000000',
#   'qty': '0.00111000',
#   'time': 1524348720266},
#  {'id': 21628329,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.27537000',
#   'time': 1524348720266},
#  {'id': 21628330,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.00125000',
#   'time': 1524348720307},
#  {'id': 21628331,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.09000000',
#   'qty': '0.28939000',
#   'time': 1524348720307},
#  {'id': 21628332,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.66000000',
#   'qty': '0.19357000',
#   'time': 1524348720561},
#  {'id': 21628333,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.07000000',
#   'qty': '0.06000000',
#   'time': 1524348721048},
#  {'id': 21628334,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.08000000',
#   'qty': '0.06000000',
#   'time': 1524348721048},
#  {'id': 21628335,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.09000000',
#   'qty': '0.00140000',
#   'time': 1524348721048},
#  {'id': 21628336,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.14000000',
#   'qty': '0.02532000',
#   'time': 1524348721048},
#  {'id': 21628337,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.06000000',
#   'qty': '0.05997000',
#   'time': 1524348722293},
#  {'id': 21628338,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.06000000',
#   'qty': '0.00003000',
#   'time': 1524348722383},
#  {'id': 21628339,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.14000000',
#   'qty': '0.01138000',
#   'time': 1524348722383},
#  {'id': 21628340,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.14000000',
#   'qty': '0.07340000',
#   'time': 1524348722383},
#  {'id': 21628341,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.14000000',
#   'qty': '0.03670000',
#   'time': 1524348722383},
#  {'id': 21628342,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.25000000',
#   'qty': '0.85000000',
#   'time': 1524348722383},
#  {'id': 21628343,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.29000000',
#   'qty': '0.40000000',
#   'time': 1524348722383},
#  {'id': 21628344,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.19760000',
#   'time': 1524348722383},
#  {'id': 21628345,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.67000000',
#   'qty': '0.33202000',
#   'time': 1524348722426},
#  {'id': 21628346,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.66000000',
#   'qty': '1.23182000',
#   'time': 1524348722426},
#  {'id': 21628347,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.28000000',
#   'qty': '0.01908000',
#   'time': 1524348725920},
#  {'id': 21628348,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.28000000',
#   'qty': '0.08613000',
#   'time': 1524348726836},
#  {'id': 21628349,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.71000000',
#   'qty': '0.06000000',
#   'time': 1524348727556},
#  {'id': 21628350,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.70000000',
#   'qty': '0.06000000',
#   'time': 1524348727556},
#  {'id': 21628351,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.69000000',
#   'qty': '0.06000000',
#   'time': 1524348727556},
#  {'id': 21628352,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.67000000',
#   'qty': '0.33202000',
#   'time': 1524348727556},
#  {'id': 21628353,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.60000000',
#   'qty': '0.81005000',
#   'time': 1524348727556},
#  {'id': 21628354,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.17000000',
#   'qty': '0.47793000',
#   'time': 1524348727556},
#  {'id': 21628355,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.20000000',
#   'qty': '0.55883000',
#   'time': 1524348729710},
#  {'id': 21628356,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.21000000',
#   'qty': '0.49000000',
#   'time': 1524348729710},
#  {'id': 21628357,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.21000000',
#   'qty': '0.75432000',
#   'time': 1524348729710},
#  {'id': 21628358,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.20000000',
#   'qty': '0.17991000',
#   'time': 1524348736171},
#  {'id': 21628359,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.20000000',
#   'qty': '0.00009000',
#   'time': 1524348736221},
#  {'id': 21628360,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.22000000',
#   'qty': '0.28425000',
#   'time': 1524348736221},
#  {'id': 21628361,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.22000000',
#   'qty': '0.00024000',
#   'time': 1524348736272},
#  {'id': 21628362,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.23000000',
#   'qty': '0.05972000',
#   'time': 1524348736272},
#  {'id': 21628363,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.23000000',
#   'qty': '0.00028000',
#   'time': 1524348737089},
#  {'id': 21628364,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.24000000',
#   'qty': '0.05968000',
#   'time': 1524348737089},
#  {'id': 21628365,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.24000000',
#   'qty': '0.00032000',
#   'time': 1524348737133},
#  {'id': 21628366,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.25000000',
#   'qty': '0.05964000',
#   'time': 1524348737133},
#  {'id': 21628367,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.25000000',
#   'qty': '0.00036000',
#   'time': 1524348737171},
#  {'id': 21628368,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.93116000',
#   'time': 1524348737171},
#  {'id': 21628369,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.51754000',
#   'time': 1524348737171},
#  {'id': 21628370,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '2.99849000',
#   'time': 1524348737960},
#  {'id': 21628371,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '0.00151000',
#   'time': 1524348738005},
#  {'id': 21628372,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.00109000',
#   'time': 1524348738005},
#  {'id': 21628373,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.42000000',
#   'qty': '0.84697000',
#   'time': 1524348738005},
#  {'id': 21628374,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.42000000',
#   'qty': '0.00303000',
#   'time': 1524348738048},
#  {'id': 21628375,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.50000000',
#   'qty': '2.74379000',
#   'time': 1524348738048},
#  {'id': 21628376,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.50000000',
#   'qty': '0.00441000',
#   'time': 1524348738179},
#  {'id': 21628377,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.57000000',
#   'qty': '0.03049000',
#   'time': 1524348738179},
#  {'id': 21628378,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.55000000',
#   'qty': '0.03496000',
#   'time': 1524348739085},
#  {'id': 21628379,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.56000000',
#   'qty': '2.96353000',
#   'time': 1524348739085},
#  {'id': 21628380,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.57000000',
#   'qty': '0.03490000',
#   'time': 1524348739474},
#  {'id': 21628381,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.55000000',
#   'qty': '2.99849000',
#   'time': 1524348740281},
#  {'id': 21628382,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.54000000',
#   'qty': '1.06013000',
#   'time': 1524348744289},
#  {'id': 21628383,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.75000000',
#   'qty': '0.33194000',
#   'time': 1524348746700},
#  {'id': 21628384,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.74000000',
#   'qty': '0.20334000',
#   'time': 1524348746700},
#  {'id': 21628385,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.64000000',
#   'qty': '0.49000000',
#   'time': 1524348746700},
#  {'id': 21628386,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.61000000',
#   'qty': '0.36600000',
#   'time': 1524348746700},
#  {'id': 21628387,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.45000000',
#   'qty': '0.06000000',
#   'time': 1524348746700},
#  {'id': 21628388,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.44000000',
#   'qty': '0.06000000',
#   'time': 1524348746700},
#  {'id': 21628389,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.41000000',
#   'qty': '0.40000000',
#   'time': 1524348746700},
#  {'id': 21628390,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.40000000',
#   'qty': '0.06000000',
#   'time': 1524348746700},
#  {'id': 21628391,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.30000000',
#   'qty': '0.84700000',
#   'time': 1524348746700},
#  {'id': 21628392,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '0.28477000',
#   'time': 1524348746726},
#  {'id': 21628393,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '1.45900000',
#   'time': 1524348747175},
#  {'id': 21628394,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '0.60699000',
#   'time': 1524348747224},
#  {'id': 21628395,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '0.36600000',
#   'time': 1524348747298},
#  {'id': 21628396,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '1.13215000',
#   'time': 1524348747436},
#  {'id': 21628397,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '0.01865000',
#   'time': 1524348747775},
#  {'id': 21628398,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.30000000',
#   'qty': '0.00162000',
#   'time': 1524348748264},
#  {'id': 21628399,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.39000000',
#   'qty': '0.26300000',
#   'time': 1524348748374},
#  {'id': 21628400,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.50000000',
#   'qty': '0.33194000',
#   'time': 1524348748374},
#  {'id': 21628401,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.57000000',
#   'qty': '0.11616000',
#   'time': 1524348748374},
#  {'id': 21628402,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.56000000',
#   'qty': '0.20334000',
#   'time': 1524348748656},
#  {'id': 21628403,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.57000000',
#   'qty': '0.21845000',
#   'time': 1524348748656},
#  {'id': 21628404,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.67000000',
#   'qty': '0.13500000',
#   'time': 1524348748656},
#  {'id': 21628405,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.77000000',
#   'qty': '0.14351000',
#   'time': 1524348748656},
#  {'id': 21628406,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.56000000',
#   'qty': '1.79000000',
#   'time': 1524348750597},
#  {'id': 21628407,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.53000000',
#   'qty': '3.00000000',
#   'time': 1524348752309},
#  {'id': 21628408,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.54000000',
#   'qty': '0.06000000',
#   'time': 1524348752309},
#  {'id': 21628409,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.55000000',
#   'qty': '0.06000000',
#   'time': 1524348752309},
#  {'id': 21628410,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.57000000',
#   'qty': '0.06000000',
#   'time': 1524348752309},
#  {'id': 21628411,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.59000000',
#   'qty': '0.22800000',
#   'time': 1524348752309},
#  {'id': 21628412,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.60000000',
#   'qty': '0.40000000',
#   'time': 1524348752309},
#  {'id': 21628413,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.77000000',
#   'qty': '0.13448000',
#   'time': 1524348752309},
#  {'id': 21628414,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.14000000',
#   'qty': '2.34628000',
#   'time': 1524348756103},
#  {'id': 21628415,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.30000000',
#   'qty': '0.03085000',
#   'time': 1524348756268},
#  {'id': 21628416,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.39000000',
#   'qty': '0.03490000',
#   'time': 1524348756391},
#  {'id': 21628417,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.14000000',
#   'qty': '0.00098000',
#   'time': 1524348756663},
#  {'id': 21628418,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.39000000',
#   'qty': '0.01865000',
#   'time': 1524348756850},
#  {'id': 21628419,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.79000000',
#   'qty': '0.08270000',
#   'time': 1524348762688},
#  {'id': 21628420,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.79000000',
#   'qty': '1.06325000',
#   'time': 1524348768473},
#  {'id': 21628421,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '0.06900000',
#   'time': 1524348769276},
#  {'id': 21628422,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '0.00080000',
#   'time': 1524348770271},
#  {'id': 21628423,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.59920000',
#   'time': 1524348770271},
#  {'id': 21628424,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '0.60000000',
#   'time': 1524348776862},
#  {'id': 21628425,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.16526000',
#   'time': 1524348776862},
#  {'id': 21628426,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.25496000',
#   'time': 1524348777266},
#  {'id': 21628427,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.56162000',
#   'time': 1524348784783},
#  {'id': 21628428,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.09989000',
#   'time': 1524348787528},
#  {'id': 21628429,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '1.27313000',
#   'time': 1524348788270},
#  {'id': 21628430,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.03945000',
#   'time': 1524348788770},
#  {'id': 21628431,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.06044000',
#   'time': 1524348790845},
#  {'id': 21628432,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.18099000',
#   'time': 1524348796046},
#  {'id': 21628433,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '3.00000000',
#   'time': 1524348811413},
#  {'id': 21628434,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '1.45900000',
#   'time': 1524348811775},
#  {'id': 21628435,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '1.11600000',
#   'time': 1524348811834},
#  {'id': 21628436,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.03599000',
#   'time': 1524348812236},
#  {'id': 21628437,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.02243000',
#   'time': 1524348813002},
#  {'id': 21628438,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.03362000',
#   'time': 1524348820189},
#  {'id': 21628439,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '1.71500000',
#   'time': 1524348824261},
#  {'id': 21628440,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.40600000',
#   'time': 1524348825171},
#  {'id': 21628441,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.89000000',
#   'qty': '0.33181000',
#   'time': 1524348825392},
#  {'id': 21628442,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.76000000',
#   'qty': '1.66127000',
#   'time': 1524348825392},
#  {'id': 21628443,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.74000000',
#   'qty': '1.36189000',
#   'time': 1524348825392},
#  {'id': 21628444,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.60000000',
#   'qty': '0.69849000',
#   'time': 1524348825392},
#  {'id': 21628445,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.49000000',
#   'qty': '0.11943000',
#   'time': 1524348825392},
#  {'id': 21628446,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.29185000',
#   'time': 1524348825411},
#  {'id': 21628447,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.32297000',
#   'time': 1524348825467},
#  {'id': 21628448,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.45212000',
#   'time': 1524348825467},
#  {'id': 21628449,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.45243000',
#   'time': 1524348825467},
#  {'id': 21628450,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.36000000',
#   'qty': '0.33181000',
#   'time': 1524348830780},
#  {'id': 21628451,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.08063000',
#   'time': 1524348830780},
#  {'id': 21628452,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.02756000',
#   'time': 1524348830780},
#  {'id': 21628453,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.10703000',
#   'time': 1524348833094},
#  {'id': 21628454,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.01000000',
#   'qty': '0.33181000',
#   'time': 1524348835459},
#  {'id': 21628455,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.00000000',
#   'qty': '1.66819000',
#   'time': 1524348835459},
#  {'id': 21628456,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.74000000',
#   'qty': '0.33181000',
#   'time': 1524348841607},
#  {'id': 21628457,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.43441000',
#   'time': 1524348841607},
#  {'id': 21628458,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.75000000',
#   'qty': '8.46603000',
#   'time': 1524348842275},
#  {'id': 21628459,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.75000000',
#   'qty': '0.75418000',
#   'time': 1524348842293},
#  {'id': 21628460,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.04000000',
#   'qty': '0.06000000',
#   'time': 1524348843339},
#  {'id': 21628461,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.03000000',
#   'qty': '0.38000000',
#   'time': 1524348843339},
#  {'id': 21628462,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.05000000',
#   'qty': '0.33179000',
#   'time': 1524348843744},
#  {'id': 21628463,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.03000000',
#   'qty': '0.06821000',
#   'time': 1524348843744},
#  {'id': 21628464,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.03000000',
#   'qty': '0.40000000',
#   'time': 1524348843793},
#  {'id': 21628465,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.06000000',
#   'qty': '0.33179000',
#   'time': 1524348845276},
#  {'id': 21628466,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.05000000',
#   'qty': '0.10821000',
#   'time': 1524348845276},
#  {'id': 21628467,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.05000000',
#   'qty': '0.00001000',
#   'time': 1524348847740},
#  {'id': 21628468,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.05000000',
#   'qty': '0.10799000',
#   'time': 1524348848436},
#  {'id': 21628469,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.05000000',
#   'qty': '0.29201000',
#   'time': 1524348850285},
#  {'id': 21628470,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.33179000',
#   'time': 1524348851511},
#  {'id': 21628471,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.79000000',
#   'qty': '0.49821000',
#   'time': 1524348851511},
#  {'id': 21628472,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.18000000',
#   'qty': '0.33179000',
#   'time': 1524348857336},
#  {'id': 21628473,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.17000000',
#   'qty': '3.00000000',
#   'time': 1524348857336},
#  {'id': 21628474,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.03000000',
#   'qty': '0.06000000',
#   'time': 1524348857336},
#  {'id': 21628475,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.02000000',
#   'qty': '0.06000000',
#   'time': 1524348857336},
#  {'id': 21628476,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.00000000',
#   'qty': '0.18573000',
#   'time': 1524348857336},
#  {'id': 21628477,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '6.36248000',
#   'time': 1524348857336},
#  {'id': 21628478,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.05129000',
#   'time': 1524348858507},
#  {'id': 21628479,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.00838000',
#   'time': 1524348861078},
#  {'id': 21628480,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.14432000',
#   'time': 1524348861507},
#  {'id': 21628481,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.03682000',
#   'time': 1524348864524},
#  {'id': 21628482,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.97000000',
#   'qty': '0.09826000',
#   'time': 1524348870185},
#  {'id': 21628483,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '1.00197000',
#   'time': 1524348880278},
#  {'id': 21628484,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.01000000',
#   'qty': '0.04926000',
#   'time': 1524348886561},
#  {'id': 21628485,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '0.00001000',
#   'time': 1524348887280},
#  {'id': 21628486,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '1.09199000',
#   'time': 1524348900241},
#  {'id': 21628487,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.20799000',
#   'time': 1524348902190},
#  {'id': 21628488,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.77000000',
#   'qty': '0.00001000',
#   'time': 1524348903430},
#  {'id': 21628489,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.00147000',
#   'time': 1524348911515},
#  {'id': 21628490,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.00059000',
#   'time': 1524348911515},
#  {'id': 21628491,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.00416000',
#   'time': 1524348912916},
#  {'id': 21628492,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.00001000',
#   'time': 1524348917536},
#  {'id': 21628493,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.78000000',
#   'qty': '0.09097000',
#   'time': 1524348921846},
#  {'id': 21628494,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.79000000',
#   'qty': '0.07231000',
#   'time': 1524348921846},
#  {'id': 21628495,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.99000000',
#   'qty': '0.08672000',
#   'time': 1524348921846},
#  {'id': 21628496,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.00030000',
#   'time': 1524348921933},
#  {'id': 21628497,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.06000000',
#   'time': 1524348924139},
#  {'id': 21628498,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.06000000',
#   'time': 1524348924139},
#  {'id': 21628499,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.06000000',
#   'time': 1524348924139},
#  {'id': 21628500,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.16000000',
#   'time': 1524348924139},
#  {'id': 21628501,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.17179000',
#   'time': 1524348941593},
#  {'id': 21628502,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.20764000',
#   'time': 1524348941593},
#  {'id': 21628503,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '1.01590000',
#   'time': 1524348945284},
#  {'id': 21628504,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.50000000',
#   'qty': '0.14899000',
#   'time': 1524348955079},
#  {'id': 21628505,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.02991000',
#   'time': 1524348955338},
#  {'id': 21628506,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '3.71132000',
#   'time': 1524348955338},
#  {'id': 21628507,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.50000000',
#   'qty': '0.00101000',
#   'time': 1524348956444},
#  {'id': 21628508,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.43000000',
#   'qty': '1.26370000',
#   'time': 1524348956444},
#  {'id': 21628509,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.43000000',
#   'qty': '0.01852000',
#   'time': 1524348957908},
#  {'id': 21628510,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '0.33168000',
#   'time': 1524348960795},
#  {'id': 21628511,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '0.25462000',
#   'time': 1524348960795},
#  {'id': 21628512,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.43000000',
#   'qty': '0.13000000',
#   'time': 1524348962893},
#  {'id': 21628513,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '0.55693000',
#   'time': 1524348974074},
#  {'id': 21628514,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.43000000',
#   'qty': '0.00047000',
#   'time': 1524348974285},
#  {'id': 21628515,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.43000000',
#   'qty': '1.03423000',
#   'time': 1524348974285},
#  {'id': 21628516,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.43000000',
#   'qty': '0.00004000',
#   'time': 1524348974288},
#  {'id': 21628517,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '0.03868000',
#   'time': 1524348975494},
#  {'id': 21628518,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.23068000',
#   'time': 1524348977702},
#  {'id': 21628519,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '1.06363000',
#   'time': 1524348982686},
#  {'id': 21628520,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '58.93637000',
#   'time': 1524348982686},
#  {'id': 21628521,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '0.22474000',
#   'time': 1524348990392},
#  {'id': 21628522,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '4.74538000',
#   'time': 1524348990392},
#  {'id': 21628523,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.14067000',
#   'time': 1524349011028},
#  {'id': 21628524,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.09926000',
#   'time': 1524349011737},
#  {'id': 21628525,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.09154000',
#   'time': 1524349011989},
#  {'id': 21628526,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.75000000',
#   'qty': '0.00021000',
#   'time': 1524349012837},
#  {'id': 21628527,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.76000000',
#   'qty': '0.14048000',
#   'time': 1524349012837},
#  {'id': 21628528,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.76000000',
#   'qty': '0.25600000',
#   'time': 1524349013278},
#  {'id': 21628529,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.25000000',
#   'qty': '0.02991000',
#   'time': 1524349019975},
#  {'id': 21628530,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.26000000',
#   'qty': '0.03224000',
#   'time': 1524349026855},
#  {'id': 21628531,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.28000000',
#   'qty': '0.20470000',
#   'time': 1524349029367},
#  {'id': 21628532,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.02991000',
#   'time': 1524349030201},
#  {'id': 21628533,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.06976000',
#   'time': 1524349030201},
#  {'id': 21628534,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.33000000',
#   'qty': '0.62105000',
#   'time': 1524349032668},
#  {'id': 21628535,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.60000000',
#   'qty': '0.11984000',
#   'time': 1524349035861},
#  {'id': 21628536,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.60000000',
#   'qty': '0.92805000',
#   'time': 1524349035972},
#  {'id': 21628537,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.33000000',
#   'qty': '0.27293000',
#   'time': 1524349036839},
#  {'id': 21628538,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.60000000',
#   'qty': '0.00007000',
#   'time': 1524349041596},
#  {'id': 21628539,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.76000000',
#   'qty': '0.68339000',
#   'time': 1524349041596},
#  {'id': 21628540,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.76000000',
#   'qty': '0.95806000',
#   'time': 1524349041611},
#  {'id': 21628541,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.02293000',
#   'time': 1524349043059},
#  {'id': 21628542,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.02000000',
#   'time': 1524349044856},
#  {'id': 21628543,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.76000000',
#   'qty': '20.00000000',
#   'time': 1524349049794},
#  {'id': 21628544,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.10000000',
#   'time': 1524349049861},
#  {'id': 21628545,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.55000000',
#   'qty': '0.20658000',
#   'time': 1524349056187},
#  {'id': 21628546,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.56000000',
#   'qty': '0.15000000',
#   'time': 1524349056733},
#  {'id': 21628547,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.55000000',
#   'qty': '0.29342000',
#   'time': 1524349056733},
#  {'id': 21628548,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.23169000',
#   'time': 1524349056733},
#  {'id': 21628549,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.33000000',
#   'qty': '0.25124000',
#   'time': 1524349056733},
#  {'id': 21628550,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.02151000',
#   'time': 1524349057169},
#  {'id': 21628551,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '0.03735000',
#   'time': 1524349059911},
#  {'id': 21628552,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '0.16900000',
#   'time': 1524349069061},
#  {'id': 21628553,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.95000000',
#   'qty': '0.12792000',
#   'time': 1524349082205},
#  {'id': 21628554,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.95000000',
#   'qty': '0.13241000',
#   'time': 1524349082205},
#  {'id': 21628555,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.07825000',
#   'time': 1524349089261},
#  {'id': 21628556,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.95000000',
#   'qty': '0.26438000',
#   'time': 1524349095307},
#  {'id': 21628557,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.00024000',
#   'time': 1524349095550},
#  {'id': 21628558,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.17428000',
#   'time': 1524349095550},
#  {'id': 21628559,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.13629000',
#   'time': 1524349095550},
#  {'id': 21628560,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.41000000',
#   'qty': '0.06214000',
#   'time': 1524349104935},
#  {'id': 21628561,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.41000000',
#   'qty': '0.06039000',
#   'time': 1524349107027},
#  {'id': 21628562,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.00100000',
#   'time': 1524349107326},
#  {'id': 21628563,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.42000000',
#   'qty': '0.39600000',
#   'time': 1524349116152},
#  {'id': 21628564,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.42000000',
#   'qty': '0.61413000',
#   'time': 1524349116325},
#  {'id': 21628565,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.40000000',
#   'qty': '0.06000000',
#   'time': 1524349116708},
#  {'id': 21628566,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.06000000',
#   'time': 1524349118698},
#  {'id': 21628567,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.86306000',
#   'time': 1524349118698},
#  {'id': 21628568,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.07694000',
#   'time': 1524349118698},
#  {'id': 21628569,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.83000000',
#   'qty': '0.36204000',
#   'time': 1524349132363},
#  {'id': 21628570,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.83000000',
#   'qty': '0.03296000',
#   'time': 1524349132611},
#  {'id': 21628571,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.83000000',
#   'qty': '0.17649000',
#   'time': 1524349132802},
#  {'id': 21628572,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.18555000',
#   'time': 1524349134218},
#  {'id': 21628573,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.41324000',
#   'time': 1524349135870},
#  {'id': 21628574,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '3.67891000',
#   'time': 1524349136126},
#  {'id': 21628575,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '3.67891000',
#   'time': 1524349136283},
#  {'id': 21628576,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.04025000',
#   'time': 1524349151609},
#  {'id': 21628577,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.96000000',
#   'qty': '0.08630000',
#   'time': 1524349154617},
#  {'id': 21628578,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.39370000',
#   'time': 1524349154617},
#  {'id': 21628579,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.12619000',
#   'time': 1524349155036},
#  {'id': 21628580,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.47000000',
#   'qty': '0.09976000',
#   'time': 1524349157798},
#  {'id': 21628581,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '2.69336000',
#   'time': 1524349160685},
#  {'id': 21628582,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '2.69336000',
#   'time': 1524349160762},
#  {'id': 21628583,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.18157000',
#   'time': 1524349161313},
#  {'id': 21628584,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '1.10210000',
#   'time': 1524349161404},
#  {'id': 21628585,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.33966000',
#   'time': 1524349161404},
#  {'id': 21628586,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '2.69336000',
#   'time': 1524349161587},
#  {'id': 21628587,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.97000000',
#   'qty': '0.11601000',
#   'time': 1524349161871},
#  {'id': 21628588,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.97000000',
#   'qty': '0.37317000',
#   'time': 1524349162308},
#  {'id': 21628589,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.60000000',
#   'time': 1524349162790},
#  {'id': 21628590,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '5.00000000',
#   'time': 1524349164315},
#  {'id': 21628591,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.48000000',
#   'qty': '0.06000000',
#   'time': 1524349166313},
#  {'id': 21628592,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.47000000',
#   'qty': '1.20149000',
#   'time': 1524349166313},
#  {'id': 21628593,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.42000000',
#   'qty': '1.42103000',
#   'time': 1524349166376},
#  {'id': 21628594,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.42000000',
#   'qty': '1.72107000',
#   'time': 1524349166398},
#  {'id': 21628595,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.42000000',
#   'qty': '1.81426000',
#   'time': 1524349166445},
#  {'id': 21628596,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '2.03838000',
#   'time': 1524349166625},
#  {'id': 21628597,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.43000000',
#   'qty': '0.05995000',
#   'time': 1524349167019},
#  {'id': 21628598,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.43000000',
#   'qty': '0.00005000',
#   'time': 1524349167317},
#  {'id': 21628599,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.23169000',
#   'time': 1524349167517},
#  {'id': 21628600,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.90000000',
#   'time': 1524349167517},
#  {'id': 21628601,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.98000000',
#   'qty': '0.90669000',
#   'time': 1524349167517},
#  {'id': 21628602,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.97000000',
#   'qty': '0.89999000',
#   'time': 1524349167588},
#  {'id': 21628603,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.37000000',
#   'qty': '0.06000000',
#   'time': 1524349167753},
#  {'id': 21628604,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.13500000',
#   'time': 1524349167753},
#  {'id': 21628605,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.19625000',
#   'time': 1524349167879},
#  {'id': 21628606,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.93000000',
#   'qty': '0.05635000',
#   'time': 1524349171705},
#  {'id': 21628607,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '0.05995000',
#   'time': 1524349179826},
#  {'id': 21628608,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.38000000',
#   'qty': '0.00005000',
#   'time': 1524349184373},
#  {'id': 21628609,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.00044000',
#   'time': 1524349184373},
#  {'id': 21628610,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.12000000',
#   'qty': '0.15540000',
#   'time': 1524349184373},
#  {'id': 21628611,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.15000000',
#   'qty': '0.33162000',
#   'time': 1524349185317},
#  {'id': 21628612,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.16000000',
#   'qty': '1.80189000',
#   'time': 1524349186810},
#  {'id': 21628613,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.87000000',
#   'qty': '0.52000000',
#   'time': 1524349201947},
#  {'id': 21628614,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.87000000',
#   'qty': '0.02020000',
#   'time': 1524349205684},
#  {'id': 21628615,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.00419000',
#   'time': 1524349209445},
#  {'id': 21628616,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.36000000',
#   'qty': '0.00284000',
# ...
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.37000000',
#   'qty': '1.88900000',
#   'time': 1524349359781},
#  {'id': 21628666,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.24205000',
#   'time': 1524349375325},
#  {'id': 21628667,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '602.00000000',
#   'qty': '0.53083000',
#   'time': 1524349385330},
#  {'id': 21628668,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '1.24664000',
#   'time': 1524349386017},
#  {'id': 21628669,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.65458000',
#   'time': 1524349386778},
#  {'id': 21628670,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.09367000',
#   'time': 1524349387050},
#  {'id': 21628671,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.19400000',
#   'time': 1524349389234},
#  {'id': 21628672,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '2.82012000',
#   'time': 1524349390434},
#  {'id': 21628673,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.22119000',
#   'time': 1524349390450},
#  {'id': 21628674,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.91267000',
#   'time': 1524349390450},
#  {'id': 21628675,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.44373000',
#   'time': 1524349390468},
#  {'id': 21628676,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.15789000',
#   'time': 1524349390488},
#  {'id': 21628677,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '1.31464000',
#   'time': 1524349390729},
#  {'id': 21628678,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.50154000',
#   'time': 1524349390747},
#  {'id': 21628679,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.17530000',
#   'time': 1524349390763},
#  {'id': 21628680,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.90258000',
#   'time': 1524349390841},
#  {'id': 21628681,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.02467000',
#   'time': 1524349393776},
#  {'id': 21628682,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.87963000',
#   'time': 1524349396157},
#  {'id': 21628683,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.46300000',
#   'time': 1524349396710},
#  {'id': 21628684,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.07820000',
#   'time': 1524349396734},
#  {'id': 21628685,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.03226000',
#   'time': 1524349396734},
#  {'id': 21628686,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.02505000',
#   'time': 1524349397346},
#  {'id': 21628687,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.99000000',
#   'qty': '0.32193000',
#   'time': 1524349397834},
#  {'id': 21628688,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.93000000',
#   'qty': '0.27574000',
#   'time': 1524349399001},
#  {'id': 21628689,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '1.09612000',
#   'time': 1524349399001},
#  {'id': 21628690,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '0.76574000',
#   'time': 1524349399001},
#  {'id': 21628691,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '1.34228000',
#   'time': 1524349399001},
#  {'id': 21628692,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.99000000',
#   'qty': '0.17899000',
#   'time': 1524349400180},
#  {'id': 21628693,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.99000000',
#   'qty': '1.31400000',
#   'time': 1524349401123},
#  {'id': 21628694,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.99000000',
#   'qty': '0.67838000',
#   'time': 1524349402010},
#  {'id': 21628695,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.28153000',
#   'time': 1524349402188},
#  {'id': 21628696,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '0.23699000',
#   'time': 1524349406237},
#  {'id': 21628697,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.20000000',
#   'qty': '0.10060000',
#   'time': 1524349408395},
#  {'id': 21628698,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.20000000',
#   'qty': '0.16279000',
#   'time': 1524349409661},
#  {'id': 21628699,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '1.45864000',
#   'time': 1524349412350},
#  {'id': 21628700,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.05000000',
#   'time': 1524349422171},
#  {'id': 21628701,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '0.36595000',
#   'time': 1524349425173},
#  {'id': 21628702,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.92000000',
#   'qty': '0.05478000',
#   'time': 1524349425189},
#  {'id': 21628703,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.99000000',
#   'qty': '0.12724000',
#   'time': 1524349426236},
#  {'id': 21628704,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.73000000',
#   'qty': '0.85000000',
#   'time': 1524349427426},
#  {'id': 21628705,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.72000000',
#   'qty': '3.31400000',
#   'time': 1524349427426},
#  {'id': 21628706,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.71000000',
#   'qty': '0.20441000',
#   'time': 1524349427426},
#  {'id': 21628707,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.49000000',
#   'qty': '0.01700000',
#   'time': 1524349430175},
#  {'id': 21628708,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.49000000',
#   'qty': '0.01900000',
#   'time': 1524349430470},
#  {'id': 21628709,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.94000000',
#   'qty': '0.06000000',
#   'time': 1524349434281},
#  {'id': 21628710,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.94000000',
#   'qty': '0.02300000',
#   'time': 1524349434281},
#  {'id': 21628711,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.94000000',
#   'qty': '0.09870000',
#   'time': 1524349435788},
#  {'id': 21628712,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.51000000',
#   'qty': '0.06000000',
#   'time': 1524349440335},
#  {'id': 21628713,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.50000000',
#   'qty': '3.31400000',
#   'time': 1524349440335},
#  {'id': 21628714,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.49000000',
#   'qty': '1.84457000',
#   'time': 1524349440347},
#  {'id': 21628715,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.49000000',
#   'qty': '0.14823000',
#   'time': 1524349440347},
#  {'id': 21628716,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.46000000',
#   'qty': '2.00000000',
#   'time': 1524349440366},
#  {'id': 21628717,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.20561000',
#   'time': 1524349442412},
#  {'id': 21628718,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.27250000',
#   'time': 1524349443173},
#  {'id': 21628719,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.48000000',
#   'qty': '0.27250000',
#   'time': 1524349450265},
#  {'id': 21628720,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.48000000',
#   'qty': '0.10300000',
#   'time': 1524349450267},
#  {'id': 21628721,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.16950000',
#   'time': 1524349450267},
#  {'id': 21628722,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.27240000',
#   'time': 1524349450384},
#  {'id': 21628723,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.27240000',
#   'time': 1524349450466},
#  {'id': 21628724,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.27230000',
#   'time': 1524349450795},
#  {'id': 21628725,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.35282000',
#   'time': 1524349450818},
#  {'id': 21628726,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '2.46687000',
#   'time': 1524349450818},
#  {'id': 21628727,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.90000000',
#   'qty': '0.06000000',
#   'time': 1524349451385},
#  {'id': 21628728,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.91000000',
#   'qty': '0.06000000',
#   'time': 1524349451385},
#  {'id': 21628729,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '0.23660000',
#   'time': 1524349451385},
#  {'id': 21628730,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.88000000',
#   'qty': '0.27230000',
#   'time': 1524349452408},
#  {'id': 21628731,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.35000000',
#   'qty': '0.00001000',
#   'time': 1524349453026},
#  {'id': 21628732,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.88000000',
#   'qty': '0.27230000',
#   'time': 1524349454122},
#  {'id': 21628733,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.88000000',
#   'qty': '0.27230000',
#   'time': 1524349454513},
#  {'id': 21628734,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '0.27240000',
#   'time': 1524349454845},
#  {'id': 21628735,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.49000000',
#   'qty': '1.01823000',
#   'time': 1524349455334},
#  {'id': 21628736,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.87000000',
#   'qty': '0.81690000',
#   'time': 1524349455334},
#  {'id': 21628737,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.88000000',
#   'qty': '1.16487000',
#   'time': 1524349455334},
#  {'id': 21628738,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.35000000',
#   'qty': '0.03659000',
#   'time': 1524349459144},
#  {'id': 21628739,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.35000000',
#   'qty': '0.07320000',
#   'time': 1524349459144},
#  {'id': 21628740,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.35000000',
#   'qty': '0.03660000',
#   'time': 1524349459144},
#  {'id': 21628741,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.31000000',
#   'qty': '0.01092000',
#   'time': 1524349459144},
#  {'id': 21628742,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.82000000',
#   'qty': '0.11169000',
#   'time': 1524349460036},
#  {'id': 21628743,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.35000000',
#   'qty': '0.29729000',
#   'time': 1524349461340},
#  {'id': 21628744,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.33000000',
#   'qty': '0.06000000',
#   'time': 1524349461354},
#  {'id': 21628745,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.32000000',
#   'qty': '0.06000000',
#   'time': 1524349461354},
#  {'id': 21628746,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.31000000',
#   'qty': '0.08894000',
#   'time': 1524349461354},
#  {'id': 21628747,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.31000000',
#   'qty': '0.51954000',
#   'time': 1524349461354},
#  {'id': 21628748,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.35000000',
#   'qty': '3.86698000',
#   'time': 1524349461856},
#  {'id': 21628749,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.35000000',
#   'qty': '0.83573000',
#   'time': 1524349462355},
#  {'id': 21628750,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.85000000',
#   'qty': '0.66342000',
#   'time': 1524349464275},
#  {'id': 21628751,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.86000000',
#   'qty': '0.62899000',
#   'time': 1524349464275},
#  {'id': 21628752,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.86000000',
#   'qty': '2.37101000',
#   'time': 1524349473923},
#  {'id': 21628753,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.86000000',
#   'qty': '0.88614000',
#   'time': 1524349474633},
#  {'id': 21628754,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.20000000',
#   'qty': '0.33230000',
#   'time': 1524349478527},
#  {'id': 21628755,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.19000000',
#   'qty': '0.31996000',
#   'time': 1524349478527},
#  {'id': 21628756,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.80000000',
#   'qty': '0.33230000',
#   'time': 1524349480868},
#  {'id': 21628757,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.81000000',
#   'qty': '0.06000000',
#   'time': 1524349480868},
#  {'id': 21628758,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.82000000',
#   'qty': '0.06000000',
#   'time': 1524349480868},
#  {'id': 21628759,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.83000000',
#   'qty': '0.06000000',
#   'time': 1524349480868},
#  {'id': 21628760,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.85000000',
#   'qty': '1.44713000',
#   'time': 1524349480868},
#  {'id': 21628761,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.85000000',
#   'qty': '0.21267000',
#   'time': 1524349482374},
#  {'id': 21628762,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.86000000',
#   'qty': '1.01032000',
#   'time': 1524349482643},
#  {'id': 21628763,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.86000000',
#   'qty': '0.05700000',
#   'time': 1524349483668},
#  {'id': 21628764,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.86000000',
#   'qty': '0.59510000',
#   'time': 1524349483689},
#  {'id': 21628765,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.24000000',
#   'qty': '0.23601000',
#   'time': 1524349483689},
#  {'id': 21628766,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.27000000',
#   'qty': '0.05632000',
#   'time': 1524349488974},
#  {'id': 21628767,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.27000000',
#   'qty': '0.00368000',
#   'time': 1524349493905},
#  {'id': 21628768,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.26000000',
#   'qty': '0.06000000',
#   'time': 1524349493905},
#  {'id': 21628769,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.25000000',
#   'qty': '0.06000000',
#   'time': 1524349493905},
#  {'id': 21628770,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.24000000',
#   'qty': '0.09629000',
#   'time': 1524349493905},
#  {'id': 21628771,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.17000000',
#   'qty': '0.37082000',
#   'time': 1524349493905},
#  {'id': 21628772,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.78000000',
#   'qty': '0.33230000',
#   'time': 1524349498222},
#  {'id': 21628773,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.92000000',
#   'qty': '1.54157000',
#   'time': 1524349498222},
#  {'id': 21628774,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '602.00000000',
#   'qty': '0.72108000',
#   'time': 1524349498222},
#  {'id': 21628775,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.24000000',
#   'qty': '0.33223000',
#   'time': 1524349499957},
#  {'id': 21628776,
#   'isBestMatch': True,
#   'isBuyerMaker': True,
#   'price': '601.23000000',
#   'qty': '1.25211000',
#   'time': 1524349499957},
#  {'id': 21628777,
#   'isBestMatch': True,
#   'isBuyerMaker': False,
#   'price': '601.70000000',
#   'qty': '0.00201000',
#   'time': 1524349509693}]

# %%
def _init_session():

    session = requests.session()
    session.headers.update({'Accept': 'application/json',
                            'User-Agent': 'binance/python'})
    return session

session = _init_session()

# %%
response = getattr(session, 'get')(uri)
json.loads(response.content.decode('utf-8'))
clear_output()

# %%
kwarg = {'check':1}

# %%
kwarg['check2'] = 2

# %%
kwarg
# Out:
# {'check': 1, 'check2': 2}

# %%
kwarg.get('check3',3)
# Out:
# 3

# %%
kwarg
# Out:
# {'check': 1, 'check2': 2}

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-9063a9f0e032> in <module>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
if "*\\d+" in "123":
    print("True")

# %%
bool(re.search(r'\d', '123'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-f914145a08bd> in <module>()
# ----> 1 bool(re.search(r'\d', '123'))
#
# NameError: name 're' is not defined

# %%
import re
bool(re.search(r'\d', '123'))
# Out:
# True

# %%
bool(re.search(r'[a-b]','1a23'))
# Out:
# True
